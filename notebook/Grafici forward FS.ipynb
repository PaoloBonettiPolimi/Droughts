# %%
import pandas as pd
import matplotlib.pyplot as plt
import itertools

# %%
df = pd.read_pickle('originale_anomalieRicalcolate2000.pickle') # non tagliato, lo uso solo per i nomi delle colonne
cols = df.columns.tolist()

# %% [markdown]
# # Con variabile Week

# %%
features = df[cols[1:2] + cols[23:]]
features.head()
# Out:
#    Week  LagoComo_Altezza_1w  LagoComo_Altezza_4w  LagoComo_Altezza_8w  \
# 0     7            -0.255714            -0.186071            -0.087321
# 1     8            -0.250000            -0.220536            -0.131786
# 2     9            -0.253571            -0.243393            -0.168125
# 3    10            -0.253571            -0.253214            -0.196518
# 4    11            -0.282143            -0.259821            -0.222946
#
#    LagoComo_Altezza_12w  LagoComo_Altezza_16w  LagoComo_Altezza_24w  \
# 0              0.069107              0.263304              0.351012
# 1              0.001012              0.171786              0.332143
# 2             -0.055655              0.106027              0.317113
# 3             -0.102679              0.046384              0.308333
# 4             -0.144821             -0.013125              0.273810
#
#    Maggiore_Altezza_1w  Maggiore_Altezza_4w  Maggiore_Altezza_8w  ...  \
# 0             0.332857             0.406071             0.654107  ...
# 1             0.304286             0.354286             0.549286  ...
# 2             0.255714             0.312500             0.456964  ...
# 3             0.237143             0.282500             0.384464  ...
# 4             0.185714             0.245714             0.325893  ...
#
#    Temp8w_piemonte sud  Temp12w_piemonte sud  Temp16w_piemonte sud  \
# 0             3.267624              3.350167              4.588464
# 1             3.788842              3.540440              4.123462
# 2             4.111640              3.511416              3.750136
# 3             4.437311              3.750828              3.706417
# 4             5.394804              4.314798              4.114912
#
#    Temp24w_piemonte sud  Temp1w_ticino  Temp4w_ticino  Temp8w_ticino  \
# 0              7.976680       1.692096       0.247981      -0.954779
# 1              7.476028       0.357593       0.323533      -0.525850
# 2              6.872391       0.104379       1.295578      -0.193304
# 3              6.426157       1.443758       0.899457       0.054039
# 4              6.124964       5.726196       1.907981       1.077981
#
#    Temp12w_ticino  Temp16w_ticino  Temp24w_ticino
# 0       -0.808797        0.569654        4.215205
# 1       -0.745402       -0.058010        3.643710
# 2       -0.807406       -0.511072        2.986071
# 3       -0.645076       -0.601180        2.440699
# 4       -0.000525       -0.129602        2.130335
#
# [5 rows x 183 columns]

# %%
cols = features.columns.tolist()
features_list = list(zip(range(len(features.columns)), features.columns.tolist()))
features_list
# Out:
# [(0, 'Week'),
#  (1, 'LagoComo_Altezza_1w'),
#  (2, 'LagoComo_Altezza_4w'),
#  (3, 'LagoComo_Altezza_8w'),
#  (4, 'LagoComo_Altezza_12w'),
#  (5, 'LagoComo_Altezza_16w'),
#  (6, 'LagoComo_Altezza_24w'),
#  (7, 'Maggiore_Altezza_1w'),
#  (8, 'Maggiore_Altezza_4w'),
#  (9, 'Maggiore_Altezza_8w'),
#  (10, 'Maggiore_Altezza_12w'),
#  (11, 'Maggiore_Altezza_16w'),
#  (12, 'Maggiore_Altezza_24w'),
#  (13, 'Lugano_Altezza_1w'),
#  (14, 'Lugano_Altezza_4w'),
#  (15, 'Lugano_Altezza_8w'),
#  (16, 'Lugano_Altezza_12w'),
#  (17, 'Lugano_Altezza_16w'),
#  (18, 'Lugano_Altezza_24w'),
#  (19, 'LagoIseo_Altezza_1w'),
#  (20, 'LagoIseo_Altezza_4w'),
#  (21, 'LagoIseo_Altezza_8w'),
#  (22, 'LagoIseo_Altezza_12w'),
#  (23, 'LagoIseo_Altezza_16w'),
#  (24, 'LagoIseo_Altezza_24w'),
#  (25, 'Prec1w_adda'),
#  (26, 'Prec4w_adda'),
#  (27, 'Prec8w_adda'),
#  (28, 'Prec12w_adda'),
#  (29, 'Prec16w_adda'),
#  (30, 'Prec24w_adda'),
#  (31, 'Prec1w_dora'),
#  (32, 'Prec4w_dora'),
#  (33, 'Prec8w_dora'),
#  (34, 'Prec12w_dora'),
#  (35, 'Prec16w_dora'),
#  (36, 'Prec24w_dora'),
#  (37, 'Prec1w_emiliani1'),
#  (38, 'Prec4w_emiliani1'),
#  (39, 'Prec8w_emiliani1'),
#  (40, 'Prec12w_emiliani1'),
#  (41, 'Prec16w_emiliani1'),
#  (42, 'Prec24w_emiliani1'),
#  (43, 'Prec1w_emiliani2'),
#  (44, 'Prec4w_emiliani2'),
#  (45, 'Prec8w_emiliani2'),
#  (46, 'Prec12w_emiliani2'),
#  (47, 'Prec16w_emiliani2'),
#  (48, 'Prec24w_emiliani2'),
#  (49, 'Prec1w_garda'),
#  (50, 'Prec4w_garda'),
#  (51, 'Prec8w_garda'),
#  (52, 'Prec12w_garda'),
#  (53, 'Prec16w_garda'),
#  (54, 'Prec24w_garda'),
#  (55, 'Prec1w_lambro'),
#  (56, 'Prec4w_lambro'),
#  (57, 'Prec8w_lambro'),
#  (58, 'Prec12w_lambro'),
#  (59, 'Prec16w_lambro'),
#  (60, 'Prec24w_lambro'),
#  (61, 'Prec1w_oglio'),
#  (62, 'Prec4w_oglio'),
#  (63, 'Prec8w_oglio'),
#  (64, 'Prec12w_oglio'),
#  (65, 'Prec16w_oglio'),
#  (66, 'Prec24w_oglio'),
#  (67, 'Prec1w_piemonte nord'),
#  (68, 'Prec4w_piemonte nord'),
#  (69, 'Prec8w_piemonte nord'),
#  (70, 'Prec12w_piemonte nord'),
#  (71, 'Prec16w_piemonte nord'),
#  (72, 'Prec24w_piemonte nord'),
#  (73, 'Prec1w_piemonte sud'),
#  (74, 'Prec4w_piemonte sud'),
#  (75, 'Prec8w_piemonte sud'),
#  (76, 'Prec12w_piemonte sud'),
#  (77, 'Prec16w_piemonte sud'),
#  (78, 'Prec24w_piemonte sud'),
#  (79, 'Prec1w_ticino'),
#  (80, 'Prec4w_ticino'),
#  (81, 'Prec8w_ticino'),
#  (82, 'Prec12w_ticino'),
#  (83, 'Prec16w_ticino'),
#  (84, 'Prec24w_ticino'),
#  (85, 'Adda_SnowDepth_Mean_4w'),
#  (86, 'Adda_SnowDepth_Mean_8w'),
#  (87, 'Adda_SnowDepth_Mean_12w'),
#  (88, 'Adda_SnowDepth_Mean_16w'),
#  (89, 'Adda_SnowDepth_Mean_24w'),
#  (90, 'Dora_SnowDepth_Mean_4w'),
#  (91, 'Dora_SnowDepth_Mean_8w'),
#  (92, 'Dora_SnowDepth_Mean_12w'),
#  (93, 'Dora_SnowDepth_Mean_16w'),
#  (94, 'Dora_SnowDepth_Mean_24w'),
#  (95, 'Garda-Mincio_SnowDepth_Mean_4w'),
#  (96, 'Garda-Mincio_SnowDepth_Mean_8w'),
#  (97, 'Garda-Mincio_SnowDepth_Mean_12w'),
#  (98, 'Garda-Mincio_SnowDepth_Mean_16w'),
#  (99, 'Garda-Mincio_SnowDepth_Mean_24w'),
#  (100, 'Oglio-Iseo_SnowDepth_Mean_4w'),
#  (101, 'Oglio-Iseo_SnowDepth_Mean_8w'),
#  (102, 'Oglio-Iseo_SnowDepth_Mean_12w'),
#  (103, 'Oglio-Iseo_SnowDepth_Mean_16w'),
#  (104, 'Oglio-Iseo_SnowDepth_Mean_24w'),
#  (105, 'Piemonte-nord_SnowDepth_Mean_1w'),
#  (106, 'Piemonte-nord_SnowDepth_Mean_4w'),
#  (107, 'Piemonte-nord_SnowDepth_Mean_8w'),
#  (108, 'Piemonte-nord_SnowDepth_Mean_12w'),
#  (109, 'Piemonte-nord_SnowDepth_Mean_16w'),
#  (110, 'Piemonte-nord_SnowDepth_Mean_24w'),
#  (111, 'Piemonte-sud_SnowDepth_Mean_1w'),
#  (112, 'Piemonte-sud_SnowDepth_Mean_4w'),
#  (113, 'Piemonte-sud_SnowDepth_Mean_8w'),
#  (114, 'Piemonte-sud_SnowDepth_Mean_12w'),
#  (115, 'Piemonte-sud_SnowDepth_Mean_16w'),
#  (116, 'Piemonte-sud_SnowDepth_Mean_24w'),
#  (117, 'Ticino_SnowDepthMean_1w'),
#  (118, 'Ticino_SnowDepthMean_4w'),
#  (119, 'Ticino_SnowDepthMean_8w'),
#  (120, 'Ticino_SnowDepthMean_12w'),
#  (121, 'Ticino_SnowDepthMean_16w'),
#  (122, 'Ticino_SnowDepthMean_24w'),
#  (123, 'Temp1w_adda'),
#  (124, 'Temp4w_adda'),
#  (125, 'Temp8w_adda'),
#  (126, 'Temp12w_adda'),
#  (127, 'Temp16w_adda'),
#  (128, 'Temp24w_adda'),
#  (129, 'Temp1w_dora'),
#  (130, 'Temp4w_dora'),
#  (131, 'Temp8w_dora'),
#  (132, 'Temp12w_dora'),
#  (133, 'Temp16w_dora'),
#  (134, 'Temp24w_dora'),
#  (135, 'Temp1w_emiliani1'),
#  (136, 'Temp4w_emiliani1'),
#  (137, 'Temp8w_emiliani1'),
#  (138, 'Temp12w_emiliani1'),
#  (139, 'Temp16w_emiliani1'),
#  (140, 'Temp24w_emiliani1'),
#  (141, 'Temp1w_emiliani2'),
#  (142, 'Temp4w_emiliani2'),
#  (143, 'Temp8w_emiliani2'),
#  (144, 'Temp12w_emiliani2'),
#  (145, 'Temp16w_emiliani2'),
#  (146, 'Temp24w_emiliani2'),
#  (147, 'Temp1w_garda'),
#  (148, 'Temp4w_garda'),
#  (149, 'Temp8w_garda'),
#  (150, 'Temp12w_garda'),
#  (151, 'Temp16w_garda'),
#  (152, 'Temp24w_garda'),
#  (153, 'Temp1w_lambro'),
#  (154, 'Temp4w_lambro'),
#  (155, 'Temp8w_lambro'),
#  (156, 'Temp12w_lambro'),
#  (157, 'Temp16w_lambro'),
#  (158, 'Temp24w_lambro'),
#  (159, 'Temp1w_oglio'),
#  (160, 'Temp4w_oglio'),
#  (161, 'Temp8w_oglio'),
#  (162, 'Temp12w_oglio'),
#  (163, 'Temp16w_oglio'),
#  (164, 'Temp24w_oglio'),
#  (165, 'Temp1w_piemonte nord'),
#  (166, 'Temp4w_piemonte nord'),
#  (167, 'Temp8w_piemonte nord'),
#  (168, 'Temp12w_piemonte nord'),
#  (169, 'Temp16w_piemonte nord'),
#  (170, 'Temp24w_piemonte nord'),
#  (171, 'Temp1w_piemonte sud'),
#  (172, 'Temp4w_piemonte sud'),
#  (173, 'Temp8w_piemonte sud'),
#  (174, 'Temp12w_piemonte sud'),
#  (175, 'Temp16w_piemonte sud'),
#  (176, 'Temp24w_piemonte sud'),
#  (177, 'Temp1w_ticino'),
#  (178, 'Temp4w_ticino'),
#  (179, 'Temp8w_ticino'),
#  (180, 'Temp12w_ticino'),
#  (181, 'Temp16w_ticino'),
#  (182, 'Temp24w_ticino')]

# %% [markdown]
# ## Target aree singole

# %% [markdown]
# ### Delta < 0.05

# %%
adda = [78]
dora = [12]
emi1 = [0]
emi2 = [0]
garda = [24]
lambro = [24]
oglio = [48]
piemnord = [46]
piemsud = [40]
ticino = [109]

aree = [adda,dora,emi1,emi2,garda,lambro,oglio,piemnord,piemsud,ticino]

# %%
aree = list(itertools.chain.from_iterable(aree))
common_features = list(dict.fromkeys(aree))
common_features.sort()
selected_features = [f[1] for f in features_list if f[0] in common_features]
feat_dict = list(zip(common_features,selected_features))

# %%
aree = [adda,dora,emi1,emi2,garda,lambro,oglio,piemnord,piemsud,ticino]
for i in range(len(aree)):
    aree[i] = [1 if f[0] in aree[i] else 0 for f in feat_dict]
    aree[i] = dict(list(zip(selected_features,aree[i])))

# %%
colors = ['blue','midnightblue','yellow','orange','aqua','steelblue','lawngreen','slategrey','red','magenta']

# %%
ax = pd.DataFrame(aree).T.plot(kind='bar',figsize=(20,8), stacked=True ,width=0.3, color=colors, rot=60, edgecolor='black')
plt.gcf().suptitle("Risultati forward FS \u03B4 < 0.05",fontsize=20)
ax.legend(['Adda','Dora','Emiliani 1', 'Emiliani 2', 'Garda-Mincio', 'Lambro', 'Oglio-Iseo', 'Piemonte Nord', 'Piemonte Sud','Ticino'])

# %% [markdown]
# ### Delta >= 0.05

# %%
adda = [78, 12, 42]
dora = [12, 122, 66]
emi1 = [0, 24, 169]
emi2 = [0, 24, 48, 12, 136, 178]
garda = [24, 132, 53, 85, 131, 138, 126, 162, 174, 168]
lambro = [24, 132, 58, 133]
oglio = [48, 131, 54, 137, 161]
piemnord = [46, 126, 26, 125, 138, 144, 180, 174, 131, 162, 168]
piemsud = [40, 10, 74, 42, 41]
ticino = [109, 41, 18]

aree = [adda,dora,emi1,emi2,garda,lambro,oglio,piemnord,piemsud,ticino]

# %%
aree = list(itertools.chain.from_iterable(aree))
common_features = list(dict.fromkeys(aree))
common_features.sort()
selected_features = [f[1] for f in features_list if f[0] in common_features]
feat_dict = list(zip(common_features,selected_features))

# %%
aree = [adda,dora,emi1,emi2,garda,lambro,oglio,piemnord,piemsud,ticino]
for i in range(len(aree)):
    aree[i] = [1 if f[0] in aree[i] else 0 for f in feat_dict]
    aree[i] = dict(list(zip(selected_features,aree[i])))

# %%
colors = ['blue','midnightblue','yellow','orange','aqua','steelblue','lawngreen','slategrey','red','magenta']

# %%
ax = pd.DataFrame(aree).T.plot(kind='bar',figsize=(20,8), stacked=True ,width=0.3, color=colors, rot=60, edgecolor='black')
plt.gcf().suptitle("Risultati forward FS \u03B4 < 0.05",fontsize=20)
ax.legend(['Adda','Dora','Emiliani 1', 'Emiliani 2', 'Garda-Mincio', 'Lambro', 'Oglio-Iseo', 'Piemonte Nord', 'Piemonte Sud','Ticino'])

# %% [markdown]
# ## Target vettore anomalie

# %%
deltamin = [0]
deltamax = [0]

# %%
selected_features = [f[1] for f in features_list if f[0] in [0]]
feat_dict = list(zip([0],selected_features))
feat_dict
# Out:
# [(0, 'Week')]

# %%
aree = [deltamin, deltamax]
for i in range(len(aree)):
    aree[i] = [1 if f[0] in aree[i] else 0 for f in feat_dict]
    aree[i] = dict(list(zip(selected_features,aree[i])))

# %%
ax = pd.DataFrame(aree).T.plot(kind='bar',figsize=(15,8), stacked=True ,width=0.2, color=colors, rot=60, edgecolor='black')
plt.gcf().suptitle("Risultati target vettore anomalie",fontsize=20)
ax.legend(['\u03B4 < 0.05','\u03B4 >= 0.05'])

# %% [markdown]
# # Senza variabile Week

# %%
cols = df.columns.tolist()
features = df[cols[23:]]
cols = features.columns.tolist()
features_list = list(zip(range(len(features.columns)), features.columns.tolist()))

# %% [markdown]
# ## Target aree singole

# %% [markdown]
# ### Delta < 0.05

# %%
adda = [77]
dora = [11]
emi1= [132]
emi2 = [92]
garda = [23]
lambro = [23]
oglio = [47]
piemnord = [45]
piemsud = [39]
ticino = [108]

aree = [adda,dora,emi1,emi2,garda,lambro,oglio,piemnord,piemsud,ticino]

# %%
aree = list(itertools.chain.from_iterable(aree))
common_features = list(dict.fromkeys(aree))
common_features.sort()
selected_features = [f[1] for f in features_list if f[0] in common_features]
feat_dict = list(zip(common_features,selected_features))

# %%
aree = [adda,dora,emi1,emi2,garda,lambro,oglio,piemnord,piemsud,ticino]
for i in range(len(aree)):
    aree[i] = [1 if f[0] in aree[i] else 0 for f in feat_dict]
    aree[i] = dict(list(zip(selected_features,aree[i])))
    
colors = ['blue','midnightblue','yellow','orange','aqua','steelblue','lawngreen','slategrey','red','magenta']
ax = pd.DataFrame(aree).T.plot(kind='bar',figsize=(20,8), stacked=True ,width=0.3, color=colors, rot=60, edgecolor='black')
plt.gcf().suptitle("Risultati forward FS \u03B4 < 0.05",fontsize=20)
ax.legend(['Adda','Dora','Emiliani 1', 'Emiliani 2', 'Garda-Mincio', 'Lambro', 'Oglio-Iseo', 'Piemonte Nord', 'Piemonte Sud','Ticino'])

# %% [markdown]
# ### Delta >= 0.05

# %%
adda = [77, 11, 41]
dora = [11, 121, 65]
emi1= [132, 45]
emi2 = [92, 41, 33]
garda = [23, 131, 52, 84, 130, 137, 125, 161, 173, 167]
lambro = [23, 131, 57, 132]
oglio = [47, 130, 53, 136, 160]
piemnord = [45, 125, 25, 124, 137, 143, 179, 173, 130, 161, 167]
piemsud = [39, 9, 73, 41, 40]
ticino = [108, 40, 17]

aree = [adda,dora,emi1,emi2,garda,lambro,oglio,piemnord,piemsud,ticino]

# %%
aree = list(itertools.chain.from_iterable(aree))
common_features = list(dict.fromkeys(aree))
common_features.sort()
selected_features = [f[1] for f in features_list if f[0] in common_features]
feat_dict = list(zip(common_features,selected_features))

aree = [adda,dora,emi1,emi2,garda,lambro,oglio,piemnord,piemsud,ticino]
for i in range(len(aree)):
    aree[i] = [1 if f[0] in aree[i] else 0 for f in feat_dict]
    aree[i] = dict(list(zip(selected_features,aree[i])))

ax = pd.DataFrame(aree).T.plot(kind='bar',figsize=(20,8), stacked=True ,width=0.3, color=colors, rot=85, edgecolor='black')
plt.gcf().suptitle("Risultati forward FS \u03B4 < 0.05",fontsize=20)
ax.legend(['Adda','Dora','Emiliani 1', 'Emiliani 2', 'Garda-Mincio', 'Lambro', 'Oglio-Iseo', 'Piemonte Nord', 'Piemonte Sud','Ticino'])

# %% [markdown]
# ## Target vettore anomalie

# %%
deltamin = [148]
deltamax = [148, 151]

aree = [deltamin,deltamax]

# %%
aree = list(itertools.chain.from_iterable(aree))
common_features = list(dict.fromkeys(aree))
common_features.sort()
selected_features = [f[1] for f in features_list if f[0] in common_features]
feat_dict = list(zip(common_features,selected_features))

aree = [deltamin,deltamax]
for i in range(len(aree)):
    aree[i] = [1 if f[0] in aree[i] else 0 for f in feat_dict]
    aree[i] = dict(list(zip(selected_features,aree[i])))

ax = pd.DataFrame(aree).T.plot(kind='bar',figsize=(15,8), stacked=True ,width=0.2, color=colors, rot=60, edgecolor='black')
plt.gcf().suptitle("Risultati target vettore anomalie",fontsize=20)
ax.legend(['\u03B4 < 0.05','\u03B4 >= 0.05'])
